# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_first_hero_name.csv')

# %%
df
# Out:
#       movie_id                                     title        hero_name
# 0        19995                                    Avatar  Sam Worthington
# 1          285  Pirates of the Caribbean: At World's End      Johnny Depp
# 2       206647                                   Spectre     Daniel Craig
# 3        49026                     The Dark Knight Rises   Christian Bale
# 4        49529                               John Carter    Taylor Kitsch
# ...        ...                                       ...              ...
# 4798      9367                               El Mariachi  Carlos Gallardo
# 4799     72766                                 Newlyweds     Edward Burns
# 4800    231617                 Signed, Sealed, Delivered      Eric Mabius
# 4801    126186                          Shanghai Calling    Daniel Henney
# 4802     25975                         My Date with Drew   Drew Barrymore
#
# [4803 rows x 3 columns]

# %%
df1 = pd.read_csv('cleaned_movie_metadata.csv')

# %%
df1
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %%
sort = df1.sort_values('popularity')

# %%
sort
# Out:
#           id                       title              original_title  \
# 4553  380097  America Is Still the Place  America Is Still the Place
# 3361   77156                  Alien Zone                  Alien Zone
# 4727   65448                Penitentiary                Penitentiary
# 4118  325140      Hum To Mohabbat Karega      Hum To Mohabbat Karega
# 4625  426067            Midnight Cabaret            Midnight Cabaret
# ...      ...                         ...                         ...
# 127    76341          Mad Max: Fury Road          Mad Max: Fury Road
# 94    118340     Guardians of the Galaxy     Guardians of the Galaxy
# 788   293660                    Deadpool                    Deadpool
# 95    157336                Interstellar                Interstellar
# 546   211672                     Minions                     Minions
#
#                                             genres  \
# 4553                                           NaN
# ...

# %%
lowest_popularity = sort.head()

# %%
lowest_popularity
# Out:
#           id                       title              original_title  \
# 4553  380097  America Is Still the Place  America Is Still the Place
# 3361   77156                  Alien Zone                  Alien Zone
# 4727   65448                Penitentiary                Penitentiary
# 4118  325140      Hum To Mohabbat Karega      Hum To Mohabbat Karega
# 4625  426067            Midnight Cabaret            Midnight Cabaret
#
#                                          genres        keywords  \
# 4553                                        NaN             NaN
# 3361  Horror, Action, Thriller, Science Fiction             NaN
# 4727                              Action, Drama  prison, boxing
# 4118                                        NaN             NaN
# 4625                                     Horror             NaN
#
#      production_companies      production_countries spoken_languages  \
# 4553                  NaN                       NaN              NaN
# ...

# %%
highest_popularity = sort.tail()

# %%
highest_popularity
# Out:
#          id                    title           original_title  \
# 127   76341       Mad Max: Fury Road       Mad Max: Fury Road
# 94   118340  Guardians of the Galaxy  Guardians of the Galaxy
# 788  293660                 Deadpool                 Deadpool
# 95   157336             Interstellar             Interstellar
# 546  211672                  Minions                  Minions
#
#                                            genres  \
# 127  Action, Adventure, Science Fiction, Thriller
# 94             Action, Science Fiction, Adventure
# 788                     Action, Adventure, Comedy
# 95              Adventure, Drama, Science Fiction
# 546          Family, Animation, Adventure, Comedy
#
#                                               keywords  \
# 127  future, chase, post-apocalyptic, dystopia, aus...
# 94   marvel comic, spaceship, space, outer space, o...
# 788  anti hero, mercenary, marvel comic, superhero,...
# 95   saving the world, artificial intelligence, fat...
# ...

# %%
#making graph between highest film popularity and lowest film popularity

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(22,10))
plt.subplot(1,2,1)
plt.plot(lowest_popularity['title'],lowest_popularity['popularity'],color='green' )
plt.title('Lowest five Popularity Movies')
plt.xlabel('Movies')
plt.ylabel('Popularity')

plt.subplot(1,2,2)
plt.plot(highest_popularity['title'],highest_popularity['popularity'],color='red')
plt.xlabel('Movies')
plt.title('Lowest five Popularity Movies')
plt.ylabel('Popularity')
# Out:
# Text(0, 0.5, 'Popularity')

# %%
df1
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4803 non-null   int64
#  1   title                 4803 non-null   object
#  2   original_title        4803 non-null   object
#  3   genres                4775 non-null   object
#  4   keywords              4391 non-null   object
#  5   production_companies  4452 non-null   object
#  6   production_countries  4629 non-null   object
#  7   spoken_languages      4716 non-null   object
#  8   release_date          4802 non-null   object
#  9   runtime               4801 non-null   float64
#  10  budget                4803 non-null   int64
#  11  revenue               4803 non-null   int64
#  12  vote_average          4803 non-null   float64
#  13  vote_count            4803 non-null   int64
#  14  status                4803 non-null   object
# ...

# %%
df3 = pd.merge(df,df1)

# %%
df3
# Out:
#       movie_id                                     title        hero_name  \
# 0        19995                                    Avatar  Sam Worthington
# 1          285  Pirates of the Caribbean: At World's End      Johnny Depp
# 2       206647                                   Spectre     Daniel Craig
# 3        49026                     The Dark Knight Rises   Christian Bale
# 4        49529                               John Carter    Taylor Kitsch
# ...        ...                                       ...              ...
# 4804      9367                               El Mariachi  Carlos Gallardo
# 4805     72766                                 Newlyweds     Edward Burns
# 4806    231617                 Signed, Sealed, Delivered      Eric Mabius
# 4807    126186                          Shanghai Calling    Daniel Henney
# 4808     25975                         My Date with Drew   Drew Barrymore
#
#           id                            original_title  \
# ...

# %%
sort_hero = df3.sort_values('rev',ascending=False)

# %%
head  = sort_hero.head()

# %%
head
# Out:
#     movie_id           title          hero_name      id  original_title  \
# 0      19995          Avatar    Sam Worthington   19995          Avatar
# 25       597         Titanic       Kate Winslet     597         Titanic
# 16     24428    The Avengers  Robert Downey Jr.   24428    The Avengers
# 28    135397  Jurassic World        Chris Pratt  135397  Jurassic World
# 44    168259       Furious 7         Vin Diesel  168259       Furious 7
#
#                                           genres  \
# 0    Action, Adventure, Fantasy, Science Fiction
# 25                      Drama, Romance, Thriller
# 16            Science Fiction, Action, Adventure
# 28  Action, Adventure, Science Fiction, Thriller
# 44                                        Action
#
#                                              keywords  \
# 0   culture clash, future, space war, space colony...
# 25  shipwreck, iceberg, ship, panic, titanic, ocea...
# 16  new york, shield, marvel comic, superhero, bas...
# ...

# %%
plt.figure(figsize=(18,12))
color = ['green','skyblue','orange','yellow','red']
plt.barh(head['hero_name'],head['revenue'],color=color,label=head['popularity'])
plt.title('High Revenue Based on Hero')
plt.xlabel('Heros Name ')
plt.ylabel('Revenue')
plt.legend()

# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_movie_metadata.csv')

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %%
sorted_language = df.sort_values('spoken_languages')

# %%
sorted_language
# Out:
#           id                                  title  \
# 607     5137  Sky Captain and the World of Tomorrow
# 2407    9675                               Sideways
# 4141   11302                                Bananas
# 220    70981                             Prometheus
# 1564    4476                    Legends of the Fall
# ...      ...                                    ...
# 4780  366967                            Dutch Kills
# 4784   24055                        The Puffy Chair
# 4793  182291                         On The Downlow
# 4797   67238                                 Cavite
# 4799   72766                              Newlyweds
#
#                              original_title  \
# 607   Sky Captain and the World of Tomorrow
# 2407                               Sideways
# 4141                                Bananas
# 220                              Prometheus
# 1564                    Legends of the Fall
# ...                                     ...
# ...

# %%
#finding the best rating movies based on relase date

# %%
sorting_data = df.groupby("production_countries")["vote_average"].max()

# %%
sorting_data
# Out:
# production_countries
# Afghanistan, Ireland, Japan                                                                                                            6.3
# Algeria, United States of America                                                                                                      0.0
# Argentina                                                                                                                              7.8
# Argentina, Denmark, Finland, France, Germany, Iceland, Italy, Netherlands, Norway, Sweden, United Kingdom, United States of America    7.6
# Argentina, Italy, Netherlands, Spain                                                                                                   6.8
#                                                                                                                                       ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,18))
sorting_data.hist()
plt.xlabel('Rating')
plt.ylabel('Production Country')
# Out:
# Text(0, 0.5, 'Production Country')

# %% [markdown]
# ### TOP 100 best movies language

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %%
sort_data2 = df.sort_values('vote_average',ascending=False).head(100)

# %%
spoken_language = sort_data2.groupby('spoken_languages')['vote_average'].max()

# %%
spoken_language
# Out:
# spoken_languages
# , English, Français, Tiếng Việt              8.0
# Deutsch, Español                             8.1
# Deutsch, Polski, עִבְרִית, English           8.3
# English                                     10.0
# English, Deutsch, Pусский                    8.0
# English, Deutsch, 广州话 / 廣州話, 日本語, Magyar     7.9
# English, Español                             8.0
# English, Español, Français                   8.3
# English, Français                            8.0
# English, Français, Italiano                  8.2
# English, Italiano, Latin                     8.4
# English, Italiano, Latin, Español            8.3
# English, Pусский                             7.9
# English, 日本語                                 7.9
# English, 日本語, Français                       8.1
# English, 普通话                                 8.2
# Español, English                             8.4
# Español, English, Français, Magyar           8.1
# Français, English                            8.2
# ...

# %%
plt.figure(figsize=(22,12))
plt.barh(spoken_language.index,spoken_language.values)
# Out:
# <BarContainer object of 28 artists>
# C:\Users\ddeba\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 24191 (\N{CJK UNIFIED IDEOGRAPH-5E7F}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\ddeba\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 24030 (\N{CJK UNIFIED IDEOGRAPH-5DDE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\ddeba\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 35805 (\N{CJK UNIFIED IDEOGRAPH-8BDD}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\ddeba\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 24291 (\N{CJK UNIFIED IDEOGRAPH-5EE3}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\ddeba\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 35441 (\N{CJK UNIFIED IDEOGRAPH-8A71}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# #T

# %%
countries = df.groupby('production_companies')['vote_average'].max().head()

# %%
countries
# Out:
# production_companies
# 100 Bares, Haddock Films S.R.L., Instituto Nacional de Cine y Artes Audiovisuales (INCAA), Televisión Española (TVE), Tornasol Films, Canal+ España, Ministerio de Cultura, Instituto de Crédito Oficial (ICO), Televisión Federal (Telefe)    7.8
# 100 Bares, Ministerio de Cultura, Instituto de Crédito Oficial (ICO), Televisión Federal (Telefe), 369 Productions, Catmandu Branded Entertainment, JEMPSA, Plural - Jempsa, Prana Animation Studios                                           6.0
# 101st Street Films                                                                                                                                                                                                                             2.7
# ...

# %%
plt.figure(figsize=(10,9))
plt.barh(countries.index,countries.values,color='purple')
# Out:
# <BarContainer object of 5 artists>

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %%
status = df.groupby('status')['runtime'].count()

# %%
plt.figure(figsize=(18,13))
plt.stackplot(status.index,status.values)
plt.tight_layout()

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %%
df1 = pd.read_csv('cleaned_first_hero_name.csv')

# %%
df
# Out:
#       movie_id                                     title        hero_name
# 0        19995                                    Avatar  Sam Worthington
# 1          285  Pirates of the Caribbean: At World's End      Johnny Depp
# 2       206647                                   Spectre     Daniel Craig
# 3        49026                     The Dark Knight Rises   Christian Bale
# 4        49529                               John Carter    Taylor Kitsch
# ...        ...                                       ...              ...
# 4798      9367                               El Mariachi  Carlos Gallardo
# 4799     72766                                 Newlyweds     Edward Burns
# 4800    231617                 Signed, Sealed, Delivered      Eric Mabius
# 4801    126186                          Shanghai Calling    Daniel Henney
# 4802     25975                         My Date with Drew   Drew Barrymore
#
# [4803 rows x 3 columns]

# %%
merge = pd.merge(df1,df)

# %%
merge
# Out:
#       movie_id                                     title        hero_name  \
# 0        19995                                    Avatar  Sam Worthington
# 1          285  Pirates of the Caribbean: At World's End      Johnny Depp
# 2       206647                                   Spectre     Daniel Craig
# 3        49026                     The Dark Knight Rises   Christian Bale
# 4        49529                               John Carter    Taylor Kitsch
# ...        ...                                       ...              ...
# 4804      9367                               El Mariachi  Carlos Gallardo
# 4805     72766                                 Newlyweds     Edward Burns
# 4806    231617                 Signed, Sealed, Delivered      Eric Mabius
# 4807    126186                          Shanghai Calling    Daniel Henney
# 4808     25975                         My Date with Drew   Drew Barrymore
#
#           id                            original_title  \
# ...

# %%
sorted_hero = merge.sort_values('revenue',ascending=False).head(10)

# %%
sorted_hero
# Out:
#      movie_id                       title          hero_name      id  \
# 0       19995                      Avatar    Sam Worthington   19995
# 25        597                     Titanic       Kate Winslet     597
# 16      24428                The Avengers  Robert Downey Jr.   24428
# 28     135397              Jurassic World        Chris Pratt  135397
# 44     168259                   Furious 7         Vin Diesel  168259
# 7       99861     Avengers: Age of Ultron  Robert Downey Jr.   99861
# 124    109445                      Frozen       Kristen Bell  109445
# 31      68721                  Iron Man 3  Robert Downey Jr.   68721
# 546    211672                     Minions     Sandra Bullock  211672
# 26     271110  Captain America: Civil War        Chris Evans  271110
#
#                  original_title                                        genres  \
# 0                        Avatar   Action, Adventure, Fantasy, Science Fiction
# ...

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_id              4809 non-null   int64
#  1   title                 4809 non-null   object
#  2   hero_name             4766 non-null   object
#  3   id                    4809 non-null   int64
#  4   original_title        4809 non-null   object
#  5   genres                4781 non-null   object
#  6   keywords              4397 non-null   object
#  7   production_companies  4457 non-null   object
#  8   production_countries  4635 non-null   object
#  9   spoken_languages      4722 non-null   object
#  10  release_date          4808 non-null   object
#  11  runtime               4807 non-null   float64
#  12  budget                4809 non-null   int64
#  13  revenue               4809 non-null   int64
#  14  vote_average          4809 non-null   float64
# ...

# %%
plt.barh(merge["spoken_languages"],merge["revenue"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 plt.barh(merge["spoken_languages"],merge["revenue"])
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3010, in barh(y, width, height, left, align, data, **kwargs)
#    2999 @_copy_docstring_and_deprecators(Axes.barh)
#    3000 def barh(
#    3001     y: float | ArrayLike,
#    (...)
#    3008     **kwargs,
#    3009 ) -> BarContainer:
# -> 3010     return gca().barh(
#    3011         y,
#    3012         width,
#    3013         height=height,
#    3014         left=left,
#    3015         align=align,
#    3016         **({"data": data} if data is not None else {}),
#    3017         **kwargs,
#    3018     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2812, in Axes.barh(self, y, width, height, left, align, data, **kwargs)
#    2693 r"""
# ...
